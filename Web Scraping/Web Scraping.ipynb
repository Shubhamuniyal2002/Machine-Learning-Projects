# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup
import numpy as np

# %%
headers= {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get("https://www.ambitionbox.com/list-of-companies?page=1",headers=headers).text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
soup.find_all('h1')[0].get_text(" ",strip=True)
# Out:
# 'Top Companies in INDIA'

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# Companies in India
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# HCLTech
# ICICI Bank
# Tech Mahindra
# Genpact
# TP
# Jio
# Axis Bank
# Concentrix Corporation
# Amazon
# Reliance Retail
# iEnergizer
# LTIMindtree
# IBM
# Popular Collections by Industries
# Popular Collections by Cities
# Popular Collections by Roles

# %%
for i in soup.find_all('div',class_='rating_text'):
    print(i.text.strip())
# Out:
# 3.3
# 3.7
# 3.6
# 3.7
# 3.6
# 3.8
# 3.5
# 3.4
# 3.9
# 3.4
# 3.6
# 3.9
# 4.4
# 3.6
# 3.6
# 3.9
# 3.9
# 4.6
# 3.6
# 3.9

# %%
company= soup.find_all('div',class_='companyCardWrapper')

# %%
len(company)
# Out:
# 20

# %%
name = []
rating = []
review = []
salary = []
Jobs = []
About = []

for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('div',class_='rating_text').text.strip())
    review.append(i.find_all('a',class_='companyCardWrapper__ActionWrapper')[0].text.strip())
    salary.append(i.find_all('a',class_='companyCardWrapper__ActionWrapper')[1].text.strip())
    Jobs.append(i.find_all('a',class_='companyCardWrapper__ActionWrapper')[3].text.strip())
    About.append(i.find('span',class_='companyCardWrapper__interLinking').text.strip())
    
d = {'Name':name, 'Rating':rating, 'Review':review, 'Salary':salary, 'Jobs':Jobs, 'About':About}

data = pd.DataFrame(d)

# %%
data
# Out:
#                       Name Rating         Review          Salary        Jobs  \
# 0                      TCS    3.3   1.2L Reviews  10.2L Salaries   4.3k Jobs
# 1                Accenture    3.7  74.2k Reviews   7.1L Salaries  34.9k Jobs
# 2                    Wipro    3.6  65.6k Reviews   4.9L Salaries    319 Jobs
# 3                Cognizant    3.7    62k Reviews   6.1L Salaries    694 Jobs
# 4                Capgemini    3.6    54k Reviews   4.9L Salaries   2.2k Jobs
# 5                HDFC Bank    3.8    53k Reviews   1.5L Salaries    315 Jobs
# 6                  Infosys    3.5  49.3k Reviews   5.3L Salaries   2.5k Jobs
# 7                  HCLTech    3.4  46.4k Reviews   3.9L Salaries    305 Jobs
# 8               ICICI Bank    3.9  46.3k Reviews   1.5L Salaries      8 Jobs
# 9            Tech Mahindra    3.4  43.7k Reviews   2.9L Salaries    614 Jobs
# 10                 Genpact    3.6  42.8k Reviews   2.4L Salaries    586 Jobs
# ...

# %%
df = pd.DataFrame()

for j in range(1,500):
    
    headers= {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage = requests.get(f"https://www.ambitionbox.com/list-of-companies?page={j}",headers=headers).text
    
    soup = BeautifulSoup(webpage, 'lxml')
    
    name = []
    rating = []
    review = []
    salary = []
    Jobs = []
    About = []

    for i in company:
        name.append(i.find('h2').text.strip())
        rating.append(i.find('div',class_='rating_text').text.strip())
        review.append(i.find_all('a',class_='companyCardWrapper__ActionWrapper')[0].text.strip())
        salary.append(i.find_all('a',class_='companyCardWrapper__ActionWrapper')[1].text.strip())
        Jobs.append(i.find_all('a',class_='companyCardWrapper__ActionWrapper')[3].text.strip())
        About.append(i.find('span',class_='companyCardWrapper__interLinking').text.strip())
    
    d = {'Name':name, 'Rating':rating, 'Review':review, 'Salary':salary, 'Jobs':Jobs, 'About':About}

    data = pd.DataFrame(d)
    
    df = pd.concat([df,data],ignore_index=True)

# %%
df
# Out:
#                  Name Rating         Review          Salary        Jobs  \
# 0                 TCS    3.3   1.2L Reviews  10.2L Salaries   4.3k Jobs
# 1           Accenture    3.7  74.2k Reviews   7.1L Salaries  34.9k Jobs
# 2               Wipro    3.6  65.6k Reviews   4.9L Salaries    319 Jobs
# 3           Cognizant    3.7    62k Reviews   6.1L Salaries    694 Jobs
# 4           Capgemini    3.6    54k Reviews   4.9L Salaries   2.2k Jobs
# ...               ...    ...            ...             ...         ...
# 9975           Amazon    3.9  31.7k Reviews   1.6L Salaries     74 Jobs
# 9976  Reliance Retail    3.9  27.5k Reviews  74.2k Salaries     97 Jobs
# 9977       iEnergizer    4.6  27.3k Reviews  24.9k Salaries     97 Jobs
# 9978      LTIMindtree    3.6  26.7k Reviews     2L Salaries    543 Jobs
# 9979              IBM    3.9    26k Reviews   2.2L Salaries   1.7k Jobs
#
#                                                   About
# ...

# %%
df.to_excel(r'D:\Machine Learning\Web Scraping\Companies Data.xlsx',index=False)
